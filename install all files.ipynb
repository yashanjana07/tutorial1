# %%
pip install sklearn
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [24 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\91911\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#       main()
#     File "C:\Users\91911\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\91911\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#       return hook(config_settings)
#              ^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
pip install joblib
# Out:
# ...
#
# ...
#                                               0.0/298.0 kB ? eta -:--:--
#      -----                                 41.0/298.0 kB 960.0 kB/s eta 0:00:01
#      ---------------                        122.9/298.0 kB 1.4 MB/s eta 0:00:01
#      -------------------                    153.6/298.0 kB 1.5 MB/s eta 0:00:01
#      ------------------------------         235.5/298.0 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------  297.0/298.0 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 298.0/298.0 kB 1.2 MB/s eta 0:00:00
# ...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install six

# %%
pip install matplotlib
# Out:
# ...
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB 330.3 kB/s eta 0:00:23
#                                               0.0/7.6 MB 330.3 kB/s eta 0:00:23
#                                               0.0/7.6 MB 330.3 kB/s eta 0:00:23
#                                               0.0/7.6 MB 151.3 kB/s eta 0:00:51
#                                               0.0/7.6 MB 151.3 kB/s eta 0:00:51
#                                               0.0/7.6 MB 151.3 kB/s eta 0:00:51
#                                               0.0/7.6 MB 151.3 kB/s eta 0:00:51
# ...

# %% [raw]
# pip install seaborn

# %%
pip install matplotlib.pyplot
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
